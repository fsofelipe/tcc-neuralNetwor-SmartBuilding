# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headerInput = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status', 'Solteiro_PMV', 'Solteiro_Temp', 'Circulacao_PMV', 'Circulacao_Temp']
headerOutput = ['JanelaSolteiroNorte', 'PortaSolteiroSul', 'SolteiroSul']

# %%
headerInput = ['Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Solteiro_PMV', 'Solteiro_Temp', 'Circulacao_PMV', 'Circulacao_Temp']
headerOutput = ['JanelaSolteiroNorte', 'PortaSolteiroSul', 'SolteiroSul']

# %%
header = headerInput+headerOutput

# %%
pmv = 'Solteiro_PMV'

# %%
all1 = pd.read_csv('../../Data/Canguçu/simulation_all1.csv')
all0 = pd.read_csv('../../Data/Canguçu/simulation_all0.csv')
SE   = pd.read_csv('../../Data/Canguçu/simulation_SE_Solteiro.csv')

# %%
x = np.linspace(-2,8, num=301)
y = np.sinc((x-2.21)*3)


fig, ax = plt.subplots()
ax.plot(x,y)

def annot_max(x,y, ax=None):
    xmax = x[np.argmax(y)]
    ymax = y.max()
    text= "x={:.3f}, y={:.3f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(0.94,0.96), **kw)

annot_max(x,y)


ax.set_ylim(-0.3,1.5)
plt.show()

# %% [markdown]
# Redimenciona o tamanho dos gráficos

# %%
plt.rcParams['figure.figsize'] = (20,7)

# %%
fig = plt.figure(1)
ax = all0[pmv].plot(label='PMV')
ax.legend()
#ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
#            arrowprops=dict(facecolor='black', shrink=0.05),
#            )

plt.show()

# %%
t05 = pd.read_csv('Resultados/RN_d05_t05.csv')

# %%
fig = plt.figure(1)
ax = t05[pmv].plot(label='PMV')
ax.legend()
Max = t05.Solteiro_PMV.idxmax()
Max_val = t05.Solteiro_PMV.iloc[Max]

ax.plot(Max,Max_val,'ro') 
plt.show()
# Out:
# -0.267297398227

# %%
Max = t05.Solteiro_PMV.idxmax()

# %%
t05.iloc[Max]
# Out:
# Hora                   22.000000
# Temperature            22.100000
# Wind_Speed              1.400000
# Wind_Direction         90.000000
# Humidity               80.000000
# Air_Density             1.156184
# Rain_Status             0.000000
# Solteiro_PMV           -0.267297
# Solteiro_Temp          25.810597
# Circulacao_PMV          0.979067
# Circulacao_Temp        25.936337
# JanelaSolteiroNorte     0.490000
# PortaSolteiroSul        0.000000
# JanelaSolteiroSul       0.480000
# Name: 2830, dtype: float64

# %%
Min = t05.Solteiro_PMV.idxmin()
t05.iloc[Min]
# Out:
# Hora                    8.000000
# Temperature            11.000000
# Wind_Speed              3.100000
# Wind_Direction         90.000000
# Humidity               85.000000
# Air_Density             1.224805
# Rain_Status             0.000000
# Solteiro_PMV           -6.233187
# Solteiro_Temp          18.005619
# Circulacao_PMV         -2.375639
# Circulacao_Temp        18.993431
# JanelaSolteiroNorte     0.490000
# PortaSolteiroSul        0.000000
# JanelaSolteiroSul       0.490000
# Name: 6608, dtype: float64
