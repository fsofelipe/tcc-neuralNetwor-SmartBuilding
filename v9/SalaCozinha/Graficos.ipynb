# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headerInput = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status', 'Jardim_PMV','Jardim_Temp','Sala_PMV','Sala_Temp','Mezanino_PMV','Mezanino_Temp']
headerOutput = ['PortaSalaNorte','JanelaSalaNorte','PortaSalaLeste','JanelaSalaSul','JanelaSalaOeste','PortaCozinhaLeste','JanelaCozinhaSul','JanelaMezaninoNorte','JanelaMezaninoSul','JanelaMezaninoOeste']
header = headerInput+headerOutput

# %%
t05 = pd.read_csv('Resultados/RN_d06_t05.csv')
all0 = pd.read_csv('../../Data/Canguçu/simulation_all0.csv')

# %%
plt.rcParams['figure.figsize'] = (15,10)

# %%
plt.figure(1)
plt.subplot(211)
plt.scatter(x=t05.Temperature, y=t05.Sala_PMV, alpha=0.5, c='r')
plt.legend()
plt.title("Distribuicao do PMV: Modelo 05")
plt.xlabel("Temperatura")
plt.ylabel("PMV")
plt.subplot(212)
plt.scatter(x=all0.Temperature, y=all0.Sala_PMV, alpha=0.5)
plt.legend()
plt.title("Distribuicao do PMV: Modelo todos janelas fechadas")
plt.xlabel("Temperatura")
plt.ylabel("PMV")
plt.savefig('Distrib_Sala.png', bbox_inches='tight')
