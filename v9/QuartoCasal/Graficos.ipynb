# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headerInput = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status', 'Jardim_PMV','Jardim_Temp','Sala_PMV','Sala_Temp','Mezanino_PMV','Mezanino_Temp']
headerOutput = ['PortaSalaNorte','JanelaSalaNorte','PortaSalaLeste','JanelaSalaSul','JanelaSalaOeste','PortaCozinhaLeste','JanelaCozinhaSul','JanelaMezaninoNorte','JanelaMezaninoSul','JanelaMezaninoOeste']
header = headerInput+headerOutput

# %%
all1 = pd.read_csv('../../Data/Canguçu/simulation_all1.csv')
all0 = pd.read_csv('../../Data/Canguçu/simulation_all0.csv')
SE   = pd.read_csv('../../Data/Canguçu/simulation_SE_001.csv')

# %%
all1_new = all1.copy()

# %%
def categoriza(row):
    if -3.5 < min([row['Sala_PMV'], row['Mezanino_PMV']]) <= -2.5:
        return -3
    if -2.5 < min([row['Sala_PMV'], row['Mezanino_PMV']]) <= -1.5:
        return -2
    if -1.5 < min([row['Sala_PMV'], row['Mezanino_PMV']]) <= -0.5:
        return -1
    if -0.5 < min([row['Sala_PMV'], row['Mezanino_PMV']]) <= +0.5:
        return 0
    if +0.5 < max([row['Sala_PMV'], row['Mezanino_PMV']]) <= +1.5:
        return 1
    if +1.5 < max([row['Sala_PMV'], row['Mezanino_PMV']]) <= +2.5:
        return 2
    if +2.5 < max([row['Sala_PMV'], row['Mezanino_PMV']]) <= +3.5:
        return 3
    if min([row['Sala_PMV'], row['Mezanino_PMV']]) < -3.5:
        return -4
    if max([row['Sala_PMV'], row['Mezanino_PMV']]) > 3.5:
        return 4
    
    

#df['col2'] = df['col1'].apply(func)

# %%
all1_new['Categoria'] = all1_new.apply(categoriza, axis=1)

# %%
all1_new['Categoria']
# Out:
# 0      -2
# 1      -3
# 2      -3
# 3      -3
# 4      -3
# 5      -3
# 6      -3
# 7      -3
# 8      -3
# 9      -3
# 10     -2
# 11     -2
# 12     -2
# 13     -1
# 14     -2
# 15     -2
# 16     -2
# 17     -3
# 18     -3
# 19     -3
# 20     -3
# 21     -3
# 22     -3
# 23     -3
# 24     -3
# 25     -3
# 26     -4
# 27     -4
# 28     -4
# 29     -4
#        ..
# 8730   -1
# 8731   -1
# 8732   -2
# 8733   -2
# 8734   -2
# 8735   -2
# 8736   -3
# 8737   -3
# 8738   -3
# 8739   -3
# 8740   -3
# 8741   -3
# 8742   -3
# 8743   -3
# 8744   -2
# 8745   -2
# 8746   -2
# 8747   -2
# 8748   -2
# 8749   -2
# 8750   -2
# 8751   -2
# 8752   -2
# 8753   -2
# 8754   -2
# 8755   -3
# 8756   -3
# 8757   -3
# 8758   -3
# 8759   -3
# Name: Categoria, Length: 8760, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (15,7)
height = [all1_new[all1_new['Categoria'] == -4].Categoria.count(),
          all1_new[all1_new['Categoria'] == -3].Categoria.count(),
          all1_new[all1_new['Categoria'] == -2].Categoria.count(),
          all1_new[all1_new['Categoria'] == -1].Categoria.count(),
          all1_new[all1_new['Categoria'] == 0].Categoria.count(),  
          all1_new[all1_new['Categoria'] == 1].Categoria.count(), 
          all1_new[all1_new['Categoria'] == 2].Categoria.count(),  
          all1_new[all1_new['Categoria'] == 3].Categoria.count(), 
          all1_new[all1_new['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
for i in (height):
    print i
# Out:
# 2322
# 2210
# 2229
# 1495
# 476
# 20
# 8
# 0
# 0

# %%
all0_new = all0.copy()
all0_new['Categoria'] = all0_new.apply(categoriza, axis=1)
plt.rcParams['figure.figsize'] = (15,7)
height = [all0_new[all0_new['Categoria'] == -4].Categoria.count(),
          all0_new[all0_new['Categoria'] == -3].Categoria.count(),
          all0_new[all0_new['Categoria'] == -2].Categoria.count(),
          all0_new[all0_new['Categoria'] == -1].Categoria.count(),
          all0_new[all0_new['Categoria'] == 0].Categoria.count(),  
          all0_new[all0_new['Categoria'] == 1].Categoria.count(), 
          all0_new[all0_new['Categoria'] == 2].Categoria.count(),  
          all0_new[all0_new['Categoria'] == 3].Categoria.count(), 
          all0_new[all0_new['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
SE_new = SE.copy()
SE_new['Categoria'] = SE_new.apply(categoriza, axis=1)
plt.rcParams['figure.figsize'] = (15,7)
height = [SE_new[SE_new['Categoria'] == -4].Categoria.count(),
          SE_new[SE_new['Categoria'] == -3].Categoria.count(),
          SE_new[SE_new['Categoria'] == -2].Categoria.count(),
          SE_new[SE_new['Categoria'] == -1].Categoria.count(),
          SE_new[SE_new['Categoria'] == 0].Categoria.count(),  
          SE_new[SE_new['Categoria'] == 1].Categoria.count(), 
          SE_new[SE_new['Categoria'] == 2].Categoria.count(),  
          SE_new[SE_new['Categoria'] == 3].Categoria.count(), 
          SE_new[SE_new['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height, tick_label=height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlabel('Categoria')
plt.ylabel(u'Frequência')

 
# Show graphic
plt.show()

# %%
t01   = pd.read_csv('Resultados/RN_d05_t01.csv')
t01['Categoria'] = t01.apply(categoriza, axis=1)
plt.rcParams['figure.figsize'] = (15,7)
height = [t01[t01['Categoria'] == -4].Categoria.count(),
          t01[t01['Categoria'] == -3].Categoria.count(),
          t01[t01['Categoria'] == -2].Categoria.count(),
          t01[t01['Categoria'] == -1].Categoria.count(),
          t01[t01['Categoria'] == 0].Categoria.count(),  
          t01[t01['Categoria'] == 1].Categoria.count(), 
          t01[t01['Categoria'] == 2].Categoria.count(),  
          t01[t01['Categoria'] == 3].Categoria.count(), 
          t01[t01['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
t01   = pd.read_csv('Resultados/RN_d05_t02.csv')
t01['Categoria'] = t01.apply(categoriza, axis=1)
plt.rcParams['figure.figsize'] = (15,7)
height = [t01[t01['Categoria'] == -4].Categoria.count(),
          t01[t01['Categoria'] == -3].Categoria.count(),
          t01[t01['Categoria'] == -2].Categoria.count(),
          t01[t01['Categoria'] == -1].Categoria.count(),
          t01[t01['Categoria'] == 0].Categoria.count(),  
          t01[t01['Categoria'] == 1].Categoria.count(), 
          t01[t01['Categoria'] == 2].Categoria.count(),  
          t01[t01['Categoria'] == 3].Categoria.count(), 
          t01[t01['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
t01   = pd.read_csv('Resultados/RN_d05_t03.csv')
t01['Categoria'] = t01.apply(categoriza, axis=1)
plt.rcParams['figure.figsize'] = (15,7)
height = [t01[t01['Categoria'] == -4].Categoria.count(),
          t01[t01['Categoria'] == -3].Categoria.count(),
          t01[t01['Categoria'] == -2].Categoria.count(),
          t01[t01['Categoria'] == -1].Categoria.count(),
          t01[t01['Categoria'] == 0].Categoria.count(),  
          t01[t01['Categoria'] == 1].Categoria.count(), 
          t01[t01['Categoria'] == 2].Categoria.count(),  
          t01[t01['Categoria'] == 3].Categoria.count(), 
          t01[t01['Categoria'] == 4].Categoria.count()]
bars = ('-4', '-3', '-2', '-1', '0', '1', '2', '3', '4')
y_pos = [0,1,2, 3, 4, 5, 6, 7, 8]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
plt.figure(1)
all0['Sala_PMV'].plot()
all1['Sala_PMV'].plot()
SE['Sala_PMV'].plot()
