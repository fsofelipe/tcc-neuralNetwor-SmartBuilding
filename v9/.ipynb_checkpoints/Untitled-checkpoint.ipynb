# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
def getSE(PMV, tempExterna, tempSala, tempJardim):
    if (PMV >= 0):
        if (tempExterna >= tempSala):
            if (tempExterna >= tempJardim):
                if (tempJardim >= tempSala):
                    return getAll0()
                else:
                    lista = getAll0()
                    lista[0][13] = 1
                    return lista
            else:
                if (tempJardim >= tempSala):
                    return getAll0()
                else:
                    return getAll0()
        else:
            if (tempExterna > tempJardim):
                if (tempJardim > tempSala):
                    return getAll0()
                else:
                    lista = getAll0()
                    lista[0][13] = 1
                    lista[0][7] = 0
                    lista[0][15] = 1
                    lista[0][16] = 1
                    lista[0][19] = 1
                    lista[0][20] = 1
                    return lista
            else:
                if (tempJardim > tempSala):
                    lista = getAll0()
                    lista[0][13] = 0
                    lista[0][7] = 1
                    lista[0][15] = 1
                    lista[0][16] = 1
                    lista[0][19] = 1
                    lista[0][20] = 1
                    return lista
                else:
                    return lista getAll1()
    else:
        if (tempExterna >= tempSala):
            if (tempExterna >= tempJardim):
                if (tempJardim >= tempSala):
                    return getAll1()
                else:
                    lista = getAll1()
                    lista[0][13] = 0
                    lista[0][7] = 1
                    lista[0][15] = 1
                    lista[0][16] = 1
                    lista[0][19] = 1
                    lista[0][20] = 1
                    return lista
            else:
                if (tempJardim >= tempSala):
                    lista = getAll1()
                    lista[0][13] = 1
                    lista[0][7] = 0
                    lista[0][15] = 1
                    lista[0][16] = 1
                    lista[0][19] = 1
                    lista[0][20] = 1
                    return lista
                else:
                    return getAll1()
        else:
            if (tempExterna > tempJardim):
                if (tempJardim > tempSala):
                    return getAll1()
                else:
                    lista = getAll0()
                    lista[0][13] = 0
                    lista[0][7] = 1
                    lista[0][15] = 0
                    lista[0][16] = 0
                    lista[0][19] = 0
                    lista[0][20] = 0
                    return lista

            else:
                if (tempJardim > tempSala):
                    lista = getAll0()
                    lista[0][13] = 1
                    lista[0][7] = 0
                    lista[0][15] = 0
                    lista[0][16] = 0
                    lista[0][19] = 0
                    lista[0][20] = 0
                    return lista
                else:
                    return getAll0()
