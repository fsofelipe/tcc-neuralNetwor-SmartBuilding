# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
header = ['Mes', 'Dia', 'Hora', 
         'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
         'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp',
         'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul' 
         ]
header_input = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
               'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp'
               ]
header_output = [
                'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul'
                ]
print len(header)
print (len(header_input))
print (len(header_output))
# Out:
# 48
# 23
# 23

# %%
all1 = pd.read_csv('../Data/Canguçu/simulation_all1.csv')
all0 = pd.read_csv('../Data/Canguçu/simulation_all0.csv')
SE   = pd.read_csv('../Data/Canguçu/simulation_SE_000.csv')

# %%
ambiente = 'QuartoSolteiro'

# %%
def is_better(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Hora'].count() - 1)):
        if ((abs(dataFrame.iloc[it - 1][PMV_label1]) >= abs(dataFrame.iloc[it][PMV_label1])) and
            (abs(dataFrame.iloc[it - 1][PMV_label2]) >= abs(dataFrame.iloc[it][PMV_label2]))):
            return True
        else:
            return False
    else:
        return False
    
    #return (dataFrame.iloc(it))

# %%
def is_better(dataFrame, it, PMV_label1):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Hora'].count() - 1)):
        if ((abs(dataFrame.iloc[it - 1][PMV_label1]) >= abs(dataFrame.iloc[it][PMV_label1])):
            return True
        else:
            return False
    else:
        return False
    
    #return (dataFrame.iloc(it))

# %%
def is_better_sig(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Temperature'].count() - 1)):
        if (((abs(dataFrame.iloc[it - 1][PMV_label1]) - abs(dataFrame.iloc[it][PMV_label1])) >= (abs(dataFrame.iloc[it][PMV_label1]) * 0.1)) and
            ((abs(dataFrame.iloc[it - 1][PMV_label2]) - abs(dataFrame.iloc[it][PMV_label2])) >= (abs(dataFrame.iloc[it][PMV_label2]) * 0.1))):
            return True
        else:
            return False
    else:
        return False

# %% [markdown]
# # MODELO d5:
# Melhora significativa 10% ou mais de conforto entre a hora anterior e o presente momento<br>
# ### Arquivos:
# - Modelo aberto<br>
# - Modelo fechado<br>
# - 150 modelos random<br>
# - Sistema Especialista

# %%
def is_better_sig(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Hora'].count() - 1)):
        if (((abs(dataFrame.iloc[it - 1][PMV_label1]) - abs(dataFrame.iloc[it][PMV_label1])) >= (abs(dataFrame.iloc[it][PMV_label1]) * 0.1)) and
            ((abs(dataFrame.iloc[it - 1][PMV_label2]) - abs(dataFrame.iloc[it][PMV_label2])) >= (abs(dataFrame.iloc[it][PMV_label2]) * 0.1))):
            return True
        else:
            return False
    else:
        return False

# %%
selected = pd.DataFrame(columns=header)

tot = 0
c = 0

# %%
SE = pd.read_csv('../Data/Canguçu/simulation_SE_001.csv')

for i in xrange(1, SE['Mes'].count() - 1):
    if (is_better_sig(SE, i, 'Sala_PMV', 'Mezanino_PMV')):
        #print i
        c = c + 1
        selected = selected.append(SE.iloc[i])

print "SE: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
# Out:
# SE: 15.9589041096% | total: 1398

# %%
for i in xrange(1, all1['Mes'].count() - 1):
    if (is_better_sig(all1, i, 'Sala_PMV', 'Mezanino_PMV')):
        #print i
        c = c + 1
        selected = selected.append(all1.iloc[i])

print "All_1: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)


tot = tot + c
c = 0
for i in xrange(1, all0['Mes'].count() - 1):
    if (is_better_sig(all0, i, 'Sala_PMV', 'Mezanino_PMV')):
        #print i
        c = c + 1
        selected = selected.append(all0.iloc[i])

print "All_0: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
# Out:
# All_1: 10.9474885845% | total: 959
# All_0: 5.70776255708% | total: 500

# %%
testes = ["%03d" % i for i in xrange(141, 151)]
print len(testes)
# Out:
# 10

# %%
sel = pd.DataFrame(columns=header)
sel.describe()

for arq in testes:
    arquivo = pd.read_csv('../Data/Canguçu/simulation_random_' + str(arq) +'.csv')
    tot = tot + c
    c = 0
    
    for i in xrange(1, arquivo['Mes'].count() - 1):
        if (is_better_sig(arquivo, i, 'Sala_PMV', 'Mezanino_PMV')):
            c = c + 1
            sel = sel.append(arquivo.iloc[i])
    
    print "Random_" + str(arq) + ": " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(sel)
# Out:
# Random_141: 11.6780821918% | total: 1023
# Random_142: 11.8607305936% | total: 1039
# Random_143: 11.7351598174% | total: 1028
# Random_144: 11.8150684932% | total: 1035
# Random_145: 11.8378995434% | total: 1037
# Random_146: 11.598173516% | total: 1016
# Random_147: 11.5410958904% | total: 1011
# Random_148: 11.7351598174% | total: 1028
# Random_149: 11.6780821918% | total: 1023
# Random_150: 11.8264840183% | total: 1036

# %%
selected.describe()
# Out:
#                  Mes            Dia           Hora    Temperature  \
# count  156674.000000  156674.000000  156674.000000  156674.000000
# mean        5.794701      16.715390      11.301569      21.426006
# std         3.829788       8.892414       4.234670       3.848446
# min         1.000000       1.000000       0.000000       1.500000
# 25%         2.000000       9.000000       9.000000      19.600000
# 50%         5.000000      17.000000      11.000000      22.100000
# 75%        10.000000      25.000000      13.000000      24.100000
# max        12.000000      31.000000      23.000000      31.300000
#
#           Wind_Speed  Wind_Direction       Humidity    Air_Density  \
# count  156674.000000   156674.000000  156674.000000  156674.000000
# mean        4.652117      181.403258      70.319970       1.115957
# std         1.904489      112.114150      15.474199       0.020970
# min         0.400000        1.000000      25.000000       1.065885
# 25%         3.200000       84.000000      58.000000       1.101247
# 50%         4.500000      156.000000      70.000000       1.113253
# 75%         5.800000      307.000000      81.000000       1.126007
# max        15.300000      360.000000      99.000000       1.222535
#
#        Rain_Status  AreaServico_PMV        ...         JanelaSalaNorte  \
# count     156674.0    156674.000000        ...           156674.000000
# mean           0.0        -1.177960        ...                0.502027
# std            0.0         0.856635        ...                0.291289
# min            0.0        -6.145238        ...                0.000000
# 25%            0.0        -1.682634        ...                0.250000
# 50%            0.0        -1.050437        ...                0.500000
# 75%            0.0        -0.582056        ...                0.750000
# max            0.0         0.958425        ...                1.000000
#
#        PortaSalaLeste  JanelaSalaSul  JanelaSalaOeste  PortaCozinhaLeste  \
# count   156674.000000  156674.000000    156674.000000      156674.000000
# mean         0.500812       0.501296         0.502227           0.499622
# std          0.291171       0.291123         0.291211           0.291642
# min          0.000000       0.000000         0.000000           0.000000
# 25%          0.250000       0.250000         0.250000           0.250000
# 50%          0.500000       0.500000         0.500000           0.500000
# 75%          0.750000       0.750000         0.760000           0.750000
# max          1.000000       1.000000         1.000000           1.000000
#
#        JanelaCozinhaSul  JanelaMezaninoNorte  JanelaMezaninoSul  \
# count     156674.000000        156674.000000      156674.000000
# mean           0.500413             0.501162           0.501866
# std            0.290895             0.291282           0.291553
# min            0.000000             0.000000           0.000000
# 25%            0.250000             0.250000           0.250000
# 50%            0.500000             0.500000           0.500000
# 75%            0.750000             0.750000           0.760000
# max            1.000000             1.000000           1.000000
#
#        JanelaMezaninoOeste  JanelaSegundoSul
# count        156674.000000          156674.0
# mean              0.501810               0.0
# std               0.291027               0.0
# min               0.000000               0.0
# 25%               0.250000               0.0
# 50%               0.500000               0.0
# 75%               0.750000               0.0
# max               1.000000               0.0
#
# [8 rows x 48 columns]

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv("Selected/d05_total.csv", index=False)
input_file.to_csv("Selected/d05_input.csv", index=False)
output_file.to_csv("Selected/d05_output.csv", index=False)

# %% [markdown]
# # Modelo d6
# Horas em conforto<br>
# -0.7 < conforto < 0.7

# %%
selected = pd.DataFrame(columns=header)
Range = 0.7
c = 0

# %%
selected = selected.append(all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <=
# mean        5.54818      17.942334      14.515203      23.392126
# std         3.49177       9.239439       5.204281       2.946061
# min         1.00000       1.000000       0.000000       6.800000
# 25%         3.00000      10.000000      12.000000      21.400000
# 50%         4.00000      19.000000      15.000000      23.600000
# 75%         8.00000      26.000000      18.000000      25.500000
# max        12.00000      31.000000      23.000000      31.600000
#
#           Wind_Speed  Wind_Direction       Humidity    Air_Density  \
# count  108105.000000   108105.000000  108105.000000  108105.000000
# mean        4.723928      185.620314      68.591934       1.104980
# std         2.073689      116.757600      16.214982       0.015396
# min         0.400000        1.000000      26.000000       1.069998
# 25%         3.100000       79.000000      56.000000       1.093135
# 50%         4.500000      166.000000      70.000000       1.103865
# 75%         6.200000      313.000000      81.000000       1.116001
# max        13.400000      360.000000      99.000000       1.191965
#
#        Rain_Status  AreaServico_PMV        ...         JanelaSalaNorte  \
# count     108105.0    108105.000000        ...           108105.000000
# mean           0.0        -0.193391        ...                0.485735
# std            0.0         0.239950        ...                0.298819
# min            0.0        -1.387668        ...                0.000000
# 25%            0.0        -0.368985        ...                0.230000
# 50%            0.0        -0.225064        ...                0.490000
# 75%            0.0        -0.013379        ...                0.740000
# max            0.0         0.596020        ...                1.000000
#
#        PortaSalaLeste  JanelaSalaSul  JanelaSalaOeste  PortaCozinhaLeste  \
# count   108105.000000  108105.000000    108105.000000      108105.000000
# mean         0.485167       0.485872         0.485469           0.486127
# std          0.299075       0.299944         0.299653           0.299369
# min          0.000000       0.000000         0.000000           0.000000
# 25%          0.230000       0.220000         0.220000           0.230000
# 50%          0.480000       0.480000         0.480000           0.480000
# 75%          0.740000       0.750000         0.750000           0.750000
# max          1.000000       1.000000         1.000000           1.000000
#
#        JanelaCozinhaSul  JanelaMezaninoNorte  JanelaMezaninoSul  \
# count     108105.000000        108105.000000      108105.000000
# mean           0.484242             0.486768           0.485213
# std            0.298958             0.299133           0.299362
# min            0.000000             0.000000           0.000000
# 25%            0.220000             0.230000           0.220000
# 50%            0.480000             0.490000           0.480000
# 75%            0.740000             0.750000           0.750000
# max            1.000000             1.000000           1.000000
#
#        JanelaMezaninoOeste  JanelaSegundoSul
# count        108105.000000          108105.0
# mean              0.485474               0.0
# std               0.298951               0.0
# min               0.000000               0.0
# 25%               0.230000               0.0
# 50%               0.480000               0.0
# 75%               0.740000               0.0
# max               1.000000               0.0
#
# [8 rows x 48 columns]

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv("Selected/d06_total.csv", index=False)
input_file.to_csv("Selected/d06_input.csv", index=False)
output_file.to_csv("Selected/d06_output.csv", index=False)

# %% [markdown]
# # Modelo d7
# Horas em conforto <br>
# Repetições do SE e do all0 para obter um melhor desempenho
# -0.7 < conforto < 0.7<br>
#
# All1<br>
# 4 x All0<br>
# 4 x SE <br>
# 108 x Randoms

# %%
selected = pd.DataFrame(columns=header)
Range = 0.7
c = 0

# %%
selected = selected.append(all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range)) & ((all1['Mezanino_PMV'] >= -Range) & (all1['Mezanino_PMV'] <= Range))])
c = all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range)) & ((all1['Mezanino_PMV'] >= -Range) & (all1['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "all1: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range)) & ((all0['Mezanino_PMV'] >= -Range) & (all0['Mezanino_PMV'] <= Range))])
c = all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range)) & ((all0['Mezanino_PMV'] >= -Range) & (all0['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "all0: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range)) & ((SE['Mezanino_PMV'] >= -Range) & (SE['Mezanino_PMV'] <= Range))])
c = SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range)) & ((SE['Mezanino_PMV'] >= -Range) & (SE['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "SE: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
# 061: 7.95662100457% | total: 697
# 062: 7.88812785388% | total: 691
# 063: 7.91095890411% | total: 693
# 064: 7.97945205479% | total: 699
# 065: 7.899543379% | total: 692
# 066: 7.86529680365% | total: 689
# 067: 7.88812785388% | total: 691
# 068: 7.76255707763% | total: 680
# 069: 7.97945205479% | total: 699
# 070: 7.79680365297% | total: 683
# 071: 7.87671232877% | total: 690
# 072: 7.83105022831% | total: 686
# 073: 7.88812785388% | total: 691
# 074: 7.77397260274% | total: 681
# 075: 7.77397260274% | total: 681
# 076: 7.97945205479% | total: 699
# 077: 7.95662100457% | total: 697
# 078: 7.95662100457% | total: 697
# 079: 7.86529680365% | total: 689
# 080: 7.87671232877% | total: 690
# 081: 7.80821917808% | total: 684
# 082: 7.92237442922% | total: 694
# 083: 7.7397260274% | total: 678
# 084: 7.83105022831% | total: 686
# 085: 7.94520547945% | total: 696
# 086: 8.00228310502% | total: 701
# 087: 7.95662100457% | total: 697
# 088: 7.95662100457% | total: 697
# 089: 7.76255707763% | total: 680
# 090: 7.94520547945% | total: 696
# 091: 7.85388127854% | total: 688
# 092: 7.79680365297% | total: 683
# 093: 7.94520547945% | total: 696
# 094: 7.96803652968% | total: 698
# 095: 7.95662100457% | total: 697
# 096: 7.93378995434% | total: 695
# 097: 7.83105022831% | total: 686
# 098: 7.96803652968% | total: 698
# 099: 7.75114155251% | total: 679
# 100: 7.8196347032% | total: 685
# 101: 7.93378995434% | total: 695
# 102: 7.94520547945% | total: 696
# 103: 7.83105022831% | total: 686
# 104: 8.03652968037% | total: 704
# 105: 7.95662100457% | total: 697
# 106: 7.79680365297% | total: 683
# 107: 7.93378995434% | total: 695
# 108: 7.85388127854% | total: 688
# 106167

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv("Selected/d07_total.csv", index=False)
input_file.to_csv("Selected/d07_input.csv", index=False)
output_file.to_csv("Selected/d07_output.csv", index=False)

# %% [markdown]
# # Modelo d8
# Horas em conforto <br>
# -0.7 < conforto < 0.7<br>
# all0 <br>
# all1 <br>
# SE <br>

# %%
selected = pd.DataFrame(columns=header)
Range = 0.7
c = 0

# %%
selected = selected.append(all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range)) & ((all1['Mezanino_PMV'] >= -Range) & (all1['Mezanino_PMV'] <= Range))])
c = all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range)) & ((all1['Mezanino_PMV'] >= -Range) & (all1['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "all1: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range)) & ((all0['Mezanino_PMV'] >= -Range) & (all0['Mezanino_PMV'] <= Range))])
c = all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range)) & ((all0['Mezanino_PMV'] >= -Range) & (all0['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "all0: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range)) & ((SE['Mezanino_PMV'] >= -Range) & (SE['Mezanino_PMV'] <= Range))])
c = SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range)) & ((SE['Mezanino_PMV'] >= -Range) & (SE['Mezanino_PMV'] <= Range))].Sala_PMV.count()
print "SE: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

print selected.Hora.count()
# Out:
# all1: 6.51826484018% | total: 571
# all0: 41.8378995434% | total: 3665
# SE: 46.3926940639% | total: 4064
# 8300

# %%
randoms = ["%03d" % i for i in xrange(1, 61)]
print len(randoms)
# Out:
# 60

# %%
for rand in randoms:
    arquivo = pd.read_csv('../Data/Canguçu/simulation_random_' + str(rand) +'.csv')
    x = arquivo[((arquivo['Sala_PMV'] >= -Range) & (arquivo['Sala_PMV'] <= Range)) & ((arquivo['Mezanino_PMV'] >= -Range) & (arquivo['Mezanino_PMV'] <= Range))]
    c = x.Sala_PMV.count()
    
    print str(rand)+": " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

    selected = selected.append(x)
    
print selected.Hora.count()
# Out:
# 001: 7.93378995434% | total: 695
# 002: 7.95662100457% | total: 697
# 003: 7.95662100457% | total: 697
# 004: 7.95662100457% | total: 697
# 005: 7.86529680365% | total: 689
# 006: 7.92237442922% | total: 694
# 007: 7.96803652968% | total: 698
# 008: 7.92237442922% | total: 694
# 009: 7.93378995434% | total: 695
# 010: 7.93378995434% | total: 695
# 011: 7.86529680365% | total: 689
# 012: 7.86529680365% | total: 689
# 013: 7.96803652968% | total: 698
# 014: 7.94520547945% | total: 696
# 015: 7.88812785388% | total: 691
# 016: 8.01369863014% | total: 702
# 017: 7.8196347032% | total: 685
# 018: 7.97945205479% | total: 699
# 019: 7.84246575342% | total: 687
# 020: 7.94520547945% | total: 696
# 021: 7.84246575342% | total: 687
# 022: 7.84246575342% | total: 687
# 023: 7.94520547945% | total: 696
# 024: 7.92237442922% | total: 694
# 025: 7.91095890411% | total: 693
# 026: 7.80821917808% | total: 684
# 027: 7.79680365297% | total: 683
# 028: 7.899543379% | total: 692
# 029: 7.76255707763% | total: 680
# 030: 7.92237442922% | total: 694
# 031: 7.87671232877% | total: 690
# 032: 8.01369863014% | total: 702
# 033: 7.88812785388% | total: 691
# 034: 7.87671232877% | total: 690
# 035: 7.7397260274% | total: 678
# 036: 7.96803652968% | total: 698
# 037: 7.96803652968% | total: 698
# 038: 7.87671232877% | total: 690
# 039: 7.87671232877% | total: 690
# 040: 7.77397260274% | total: 681
# 041: 7.77397260274% | total: 681
# 042: 7.93378995434% | total: 695
# 043: 7.83105022831% | total: 686
# 044: 7.97945205479% | total: 699
# 045: 7.99086757991% | total: 700
# 046: 7.84246575342% | total: 687
# 047: 7.7397260274% | total: 678
# 048: 7.93378995434% | total: 695
# 049: 7.80821917808% | total: 684
# 050: 7.83105022831% | total: 686
# 051: 7.94520547945% | total: 696
# 052: 7.8196347032% | total: 685
# 053: 7.86529680365% | total: 689
# 054: 7.94520547945% | total: 696
# 055: 7.85388127854% | total: 688
# 056: 7.86529680365% | total: 689
# 057: 7.96803652968% | total: 698
# 058: 7.94520547945% | total: 696
# 059: 7.93378995434% | total: 695
# 060: 8.02511415525% | total: 703
# 49807

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv("Selected/d08_total.csv", index=False)
input_file.to_csv("Selected/d08_input.csv", index=False)
output_file.to_csv("Selected/d08_output.csv", index=False)

# %% [markdown]
# # Modelo d9
# Horas em conforto <br>
# -0.7 < conforto < 0.7<br>
# all0 <br>
# all1 <br>
# SE <br>
#
# **Apenas PMV sala**

# %%
selected = pd.DataFrame(columns=header)
Range = 0.7
c = 0

# %%
selected = selected.append(all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range))])
c = all1[((all1['Sala_PMV'] >= -Range) & (all1['Sala_PMV'] <= Range))].Sala_PMV.count()
print "all1: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range))])
c = all0[((all0['Sala_PMV'] >= -Range) & (all0['Sala_PMV'] <= Range))].Sala_PMV.count()
print "all0: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range))])
c = SE[((SE['Sala_PMV'] >= -Range) & (SE['Sala_PMV'] <= Range))].Sala_PMV.count()
print "SE: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)