# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
header = ['Mes', 'Dia', 'Hora', 
         'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
         'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp',
         'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul' 
         ]
header_input = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
               'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp'
               ]
header_output = [
                'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul'
                ]
print len(header)
print (len(header_input))
print (len(header_output))
# Out:
# 48
# 23
# 23

# %%
all1 = pd.read_csv('../Data/Canguçu/simulation_all1.csv')
all0 = pd.read_csv('../Data/Canguçu/simulation_all0.csv')
SE   = pd.read_csv('../Data/Canguçu/simulation_SE_000.csv')

# %%
ambiente = 'QuartoSolteiro'
pmv = 'Casal_PMV'

# %% [markdown]
# # FUNÇÕES DE SELEÇÃO DE DADOS

# %% [markdown]
# Usar se for selecionar para a **sala/mezanino**

# %%
def is_better(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Hora'].count() - 1)):
        if ((abs(dataFrame.iloc[it - 1][PMV_label1]) >= abs(dataFrame.iloc[it][PMV_label1])) and
            (abs(dataFrame.iloc[it - 1][PMV_label2]) >= abs(dataFrame.iloc[it][PMV_label2]))):
            return True
        else:
            return False
    else:
        return False
    
    #return (dataFrame.iloc(it))

# %%
def is_better_sig(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Temperature'].count() - 1)):
        if (((abs(dataFrame.iloc[it - 1][PMV_label1]) - abs(dataFrame.iloc[it][PMV_label1])) >= (abs(dataFrame.iloc[it][PMV_label1]) * 0.1)) and
            ((abs(dataFrame.iloc[it - 1][PMV_label2]) - abs(dataFrame.iloc[it][PMV_label2])) >= (abs(dataFrame.iloc[it][PMV_label2]) * 0.1))):
            return True
        else:
            return False
    else:
        return False

# %% [markdown]
# Usar se for para selecionar para os **dormitórios**

# %%
def is_better(dataFrame, it, PMV_label1):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Temperature'].count() - 1)):
        if (abs(dataFrame.iloc[it - 1][PMV_label1]) >= abs(dataFrame.iloc[it][PMV_label1])):
            return True
        else:
            return False
    else:
        return False
    
    #return (dataFrame.iloc(it))

# %%
def is_better_sig(dataFrame, it, PMV_label1):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Temperature'].count() - 1)):
        if ((abs(dataFrame.iloc[it - 1][PMV_label1]) - abs(dataFrame.iloc[it][PMV_label1])) >= (abs(dataFrame.iloc[it][PMV_label1]) * 0.1)):
            return True
        else:
            return False
    else:
        return False

# %% [markdown]
# # MODELO d5:
# Melhora significativa 10% ou mais de conforto entre a hora anterior e o presente momento<br>
# ### Arquivos:
# - Modelo aberto<br>
# - Modelo fechado<br>
# - 150 modelos random<br>
# - Sistema Especialista

# %%
selected = pd.DataFrame(columns=header)
tot = 0
c = 0

# %%
c = 0
for i in xrange(1, SE['Temperature'].count() - 1):
    if (is_better_sig(SE, i, pmv)):
        #print i
        c = c + 1
        #selected = selected.append(SE.iloc[i])

print "SE: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

for i in xrange(1, all1['Temperature'].count() - 1):
    if (is_better_sig(all1, i, pmv)):
        c = c + 1
        selected = selected.append(all1.iloc[i])

print "All_1: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)


c = 0
for i in xrange(1, all0['Temperature'].count() - 1):
    if (is_better_sig(all0, i, pmv)):
        #print i
        c = c + 1
        selected = selected.append(all0.iloc[i])

print "All_0: " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
# Out:
# SE: 4.85159817352% | total: 425
# All_1: 9.07534246575% | total: 795
# All_0: 3.98401826484% | total: 349

# %%
testes = ["%03d" % i for i in xrange(121, 151)]
print len(testes)
# Out:
# 30

# %%
sel = pd.DataFrame(columns=header)
sel.describe()

for arq in testes:
    arquivo = pd.read_csv('../Data/Canguçu/simulation_random_' + str(arq) +'.csv')
    tot = tot + c
    c = 0
    
    for i in xrange(1, arquivo['Mes'].count() - 1):
        if (is_better_sig(arquivo, i, 'Solteiro_PMV')):
            c = c + 1
            sel = sel.append(arquivo.iloc[i])
    
    print "Random_" + str(arq) + ": " +  str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

selected = selected.append(sel)
# Out:
# Random_121: 7.83105022831% | total: 686
# Random_122: 7.79680365297% | total: 683
# Random_123: 7.45433789954% | total: 653
# Random_124: 7.48858447489% | total: 656
# Random_125: 7.92237442922% | total: 694
# Random_126: 7.72831050228% | total: 677
# Random_127: 7.93378995434% | total: 695
# Random_128: 7.85388127854% | total: 688
# Random_129: 7.76255707763% | total: 680
# Random_130: 7.86529680365% | total: 689
# Random_131: 7.78538812785% | total: 682
# Random_132: 7.70547945205% | total: 675
# Random_133: 7.69406392694% | total: 674
# Random_134: 7.68264840183% | total: 673
# Random_135: 7.85388127854% | total: 688
# Random_136: 7.43150684932% | total: 651
# Random_137: 7.36301369863% | total: 645
# Random_138: 7.40867579909% | total: 649
# Random_139: 7.92237442922% | total: 694
# Random_140: 7.67123287671% | total: 672
# Random_141: 7.29452054795% | total: 639
# Random_142: 7.75114155251% | total: 679
# Random_143: 7.47716894977% | total: 655
# Random_144: 7.51141552511% | total: 658
# Random_145: 7.71689497717% | total: 676
# Random_146: 7.52283105023% | total: 659
# Random_147: 7.46575342466% | total: 654
# Random_148: 7.48858447489% | total: 656
# Random_149: 7.54566210046% | total: 661
# Random_150: 7.19178082192% | total: 630

# %%
selected.describe()
# Out:
#                 Mes           Dia          Hora   Temperature    Wind_Speed  \
# count  54422.000000  54422.000000  54422.000000  54422.000000  54422.000000
# mean       5.500753     16.430028     10.112565     20.658311      4.815108
# std        3.952743      9.193868      6.071477      4.008726      2.020350
# min        1.000000      1.000000      0.000000      6.900000      0.400000
# 25%        2.000000      8.000000      6.000000     17.400000      3.300000
# 50%        4.000000     17.000000     10.000000     20.600000      4.700000
# 75%       10.000000     25.000000     13.000000     24.100000      6.100000
# max       12.000000     31.000000     23.000000     32.800000     15.800000
#
#        Wind_Direction      Humidity   Air_Density  Rain_Status  \
# count    54422.000000  54422.000000  54422.000000      54422.0
# mean       180.879608     78.442817      1.117017          0.0
# std        110.069698     17.624143      0.019243          0.0
# min          1.000000     25.000000      1.062356          0.0
# 25%         89.000000     65.000000      1.101872          0.0
# 50%        159.000000     81.000000      1.115530          0.0
# 75%        305.000000     96.000000      1.131348          0.0
# max        360.000000     99.000000      1.191965          0.0
#
#        AreaServico_PMV        ...         JanelaSalaNorte  PortaSalaLeste  \
# count     54422.000000        ...            54422.000000    54422.000000
# mean         -1.207844        ...                0.498660        0.499906
# std           0.854410        ...                0.292503        0.293735
# min          -5.244322        ...                0.000000        0.000000
# 25%          -1.767001        ...                0.250000        0.240000
# 50%          -1.074309        ...                0.500000        0.500000
# 75%          -0.595022        ...                0.750000        0.760000
# max           1.035015        ...                1.000000        1.000000
#
#        JanelaSalaSul  JanelaSalaOeste  PortaCozinhaLeste  JanelaCozinhaSul  \
# count   54422.000000     54422.000000       54422.000000      54422.000000
# mean        0.500809         0.498963           0.496895          0.500375
# std         0.292724         0.292310           0.291254          0.292495
# min         0.000000         0.000000           0.000000          0.000000
# 25%         0.250000         0.250000           0.250000          0.250000
# 50%         0.500000         0.500000           0.490000          0.500000
# 75%         0.760000         0.750000           0.750000          0.750000
# max         1.000000         1.000000           1.000000          1.000000
#
#        JanelaMezaninoNorte  JanelaMezaninoSul  JanelaMezaninoOeste  \
# count         54422.000000       54422.000000         54422.000000
# mean              0.500698           0.500504             0.500112
# std               0.292698           0.292322             0.292707
# min               0.000000           0.000000             0.000000
# 25%               0.250000           0.250000             0.250000
# 50%               0.500000           0.500000             0.500000
# 75%               0.760000           0.750000             0.750000
# max               1.000000           1.000000             1.000000
#
#        JanelaSegundoSul
# count           54422.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0
#
# [8 rows x 48 columns]

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv(ambiente + "/Selected/d05_total.csv", index=False)
input_file.to_csv(ambiente + "/Selected/d05_input.csv", index=False)
output_file.to_csv(ambiente + "/Selected/d05_output.csv", index=False)

# %% [markdown]
# # Modelo d6
# Horas em conforto<br>
# -0.7 < conforto < 0.7

# %%
selected = pd.DataFrame(columns=header)
print selected.Sala_PMV.count()
Range = 0.7
c = 0
# Out:
# 0

# %%
selected = selected.append(all1[((all1[pmv] >= -Range) & (all1[pmv] <= Range))])
c = all1[((all1[pmv] >= -Range) & (all1[pmv] <= Range))].Solteiro_PMV.count()
print "all1: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
selected = selected.append(all0[((all0[pmv] >= -Range) & (all0[pmv] <= Range)) ])
c = all0[((all0[pmv] >= -Range) & (all0[pmv] <= Range))].Solteiro_PMV.count()
print "all0: " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)
# Out:
# all1: 0.0342465753425% | total: 3
# all0: 16.6894977169% | total: 1462

# %%
randoms = ["%03d" % i for i in xrange(1, 151)]
print len(randoms)
# Out:
# 150

# %%
for rand in randoms:
    arquivo = pd.read_csv('../Data/Canguçu/simulation_random_' + str(rand) +'.csv')
    x = arquivo[((arquivo[pmv] >= -Range) & (arquivo[pmv] <= Range))]
    c = x.Solteiro_PMV.count()
    
    print str(rand)+": " + str((c * 100.0)/8760.0) + "%" + " | total: " + str(c)

    selected = selected.append(x)
# Out:
# 001: 0.0570776255708% | total: 5
# 002: 0.0342465753425% | total: 3
# 003: 0.0456621004566% | total: 4
# 004: 0.0342465753425% | total: 3
# 005: 0.0570776255708% | total: 5
# 006: 0.0456621004566% | total: 4
# 007: 0.0456621004566% | total: 4
# 008: 0.0456621004566% | total: 4
# 009: 0.0228310502283% | total: 2
# 010: 0.0684931506849% | total: 6
# 011: 0.0342465753425% | total: 3
# 012: 0.0799086757991% | total: 7
# 013: 0.0570776255708% | total: 5
# 014: 0.0456621004566% | total: 4
# 015: 0.0913242009132% | total: 8
# 016: 0.0684931506849% | total: 6
# 017: 0.0570776255708% | total: 5
# 018: 0.0684931506849% | total: 6
# 019: 0.0228310502283% | total: 2
# 020: 0.0456621004566% | total: 4
# 021: 0.0228310502283% | total: 2
# 022: 0.0456621004566% | total: 4
# 023: 0.0570776255708% | total: 5
# 024: 0.0228310502283% | total: 2
# 025: 0.0570776255708% | total: 5
# 026: 0.0342465753425% | total: 3
# 027: 0.0228310502283% | total: 2
# 028: 0.0684931506849% | total: 6
# 029: 0.0570776255708% | total: 5
# 030: 0.0456621004566% | total: 4
# 031: 0.0570776255708% | total: 5
# 032: 0.0570776255708% | total: 5
# 033: 0.0342465753425% | total: 3
# 034: 0.0570776255708% | total: 5
# 035: 0.0684931506849% | total: 6
# 036: 0.0228310502283% | total: 2
# 037: 0.0684931506849% | total: 6
# 038: 0.0228310502283% | total: 2
# 039: 0.0570776255708% | total: 5
# 040: 0.0570776255708% | total: 5
# 041: 0.0456621004566% | total: 4
# 042: 0.0570776255708% | total: 5
# 043: 0.0456621004566% | total: 4
# 044: 0.0456621004566% | total: 4
# 045: 0.0228310502283% | total: 2
# 046: 0.0342465753425% | total: 3
# 047: 0.0684931506849% | total: 6
# 048: 0.0456621004566% | total: 4
# 049: 0.0570776255708% | total: 5
# 050: 0.0570776255708% | total: 5
# 051: 0.0456621004566% | total: 4
# 052: 0.0570776255708% | total: 5
# 053: 0.0456621004566% | total: 4
# 054: 0.0342465753425% | total: 3
# 055: 0.0456621004566% | total: 4
# 056: 0.0570776255708% | total: 5
# 057: 0.0342465753425% | total: 3
# 058: 0.0228310502283% | total: 2
# 059: 0.0456621004566% | total: 4
# 060: 0.0456621004566% | total: 4
# 061: 0.0456621004566% | total: 4
# 062: 0.0570776255708% | total: 5
# 063: 0.0342465753425% | total: 3
# 064: 0.0342465753425% | total: 3
# 065: 0.0342465753425% | total: 3
# 066: 0.0456621004566% | total: 4
# 067: 0.0570776255708% | total: 5
# 068: 0.0342465753425% | total: 3
# 069: 0.0570776255708% | total: 5
# 070: 0.0570776255708% | total: 5
# 071: 0.0570776255708% | total: 5
# 072: 0.0570776255708% | total: 5
# 073: 0.0342465753425% | total: 3
# 074: 0.0799086757991% | total: 7
# 075: 0.0684931506849% | total: 6
# 076: 0.0684931506849% | total: 6
# 077: 0.0799086757991% | total: 7
# 078: 0.0456621004566% | total: 4
# 079: 0.0342465753425% | total: 3
# 080: 0.0456621004566% | total: 4
# 081: 0.0342465753425% | total: 3
# 082: 0.0570776255708% | total: 5
# 083: 0.0342465753425% | total: 3
# 084: 0.0570776255708% | total: 5
# 085: 0.0456621004566% | total: 4
# 086: 0.0456621004566% | total: 4
# 087: 0.0570776255708% | total: 5
# 088: 0.0342465753425% | total: 3
# 089: 0.0684931506849% | total: 6
# 090: 0.0456621004566% | total: 4
# 091: 0.0342465753425% | total: 3
# 092: 0.0456621004566% | total: 4
# 093: 0.0799086757991% | total: 7
# 094: 0.0684931506849% | total: 6
# 095: 0.0342465753425% | total: 3
# 096: 0.0456621004566% | total: 4
# 097: 0.0342465753425% | total: 3
# 098: 0.0684931506849% | total: 6
# 099: 0.0456621004566% | total: 4
# 100: 0.0456621004566% | total: 4
# 101: 0.0684931506849% | total: 6
# 102: 0.0228310502283% | total: 2
# 103: 0.0913242009132% | total: 8
# 104: 0.0570776255708% | total: 5
# 105: 0.0913242009132% | total: 8
# 106: 0.0228310502283% | total: 2
# 107: 0.0342465753425% | total: 3
# 108: 0.0684931506849% | total: 6
# 109: 0.0456621004566% | total: 4
# 110: 0.0456621004566% | total: 4
# 111: 0.0342465753425% | total: 3
# 112: 0.0913242009132% | total: 8
# 113: 0.0342465753425% | total: 3
# 114: 0.0342465753425% | total: 3
# 115: 0.0456621004566% | total: 4
# 116: 0.0570776255708% | total: 5
# 117: 0.0570776255708% | total: 5
# 118: 0.0570776255708% | total: 5
# 119: 0.0456621004566% | total: 4
# 120: 0.0570776255708% | total: 5
# 121: 0.0456621004566% | total: 4
# 122: 0.0570776255708% | total: 5
# 123: 0.0342465753425% | total: 3
# 124: 0.0342465753425% | total: 3
# 125: 0.0570776255708% | total: 5
# 126: 0.0342465753425% | total: 3
# 127: 0.0684931506849% | total: 6
# 128: 0.0114155251142% | total: 1
# 129: 0.0456621004566% | total: 4
# 130: 0.0570776255708% | total: 5
# 131: 0.0456621004566% | total: 4
# 132: 0.0456621004566% | total: 4
# 133: 0.0342465753425% | total: 3
# 134: 0.0570776255708% | total: 5
# 135: 0.0228310502283% | total: 2
# 136: 0.0456621004566% | total: 4
# 137: 0.0799086757991% | total: 7
# 138: 0.0570776255708% | total: 5
# 139: 0.0799086757991% | total: 7
# 140: 0.0456621004566% | total: 4
# 141: 0.0456621004566% | total: 4
# 142: 0.0456621004566% | total: 4
# 143: 0.0456621004566% | total: 4
# 144: 0.0570776255708% | total: 5
# 145: 0.0456621004566% | total: 4
# 146: 0.0342465753425% | total: 3
# 147: 0.0456621004566% | total: 4
# 148: 0.0570776255708% | total: 5
# 149: 0.0456621004566% | total: 4
# 150: 0.0570776255708% | total: 5

# %%
selected.describe()
# Out:
#                Mes          Dia         Hora  Temperature   Wind_Speed  \
# count  2112.000000  2112.000000  2112.000000  2112.000000  2112.000000
# mean      7.304924    14.337595    12.685606    23.410890     4.950142
# std       4.155187    11.103541     6.530736     5.275737     1.769950
# min       1.000000     1.000000     0.000000     8.100000     0.400000
# 25%       4.000000     2.000000     7.000000    19.500000     4.000000
# 50%       8.000000    13.000000    15.000000    22.500000     4.800000
# 75%      11.000000    26.000000    17.000000    28.100000     5.800000
# max      12.000000    31.000000    23.000000    32.800000    13.400000
#
#        Wind_Direction     Humidity  Air_Density  Rain_Status  AreaServico_PMV  \
# count     2112.000000  2112.000000  2112.000000       2112.0      2112.000000
# mean       176.949811    73.754261     1.101926          0.0         0.379376
# std        114.417311    20.312428     0.025629          0.0         0.280412
# min          1.000000    25.000000     1.066011          0.0        -0.513737
# 25%         83.750000    57.000000     1.078259          0.0         0.172087
# 50%        137.000000    77.000000     1.102828          0.0         0.378054
# 75%        319.250000    94.000000     1.121592          0.0         0.582977
# max        360.000000    99.000000     1.180089          0.0         1.035015
#
#              ...         JanelaSalaNorte  PortaSalaLeste  JanelaSalaSul  \
# count        ...             2112.000000     2112.000000    2112.000000
# mean         ...                0.157921        0.154219       0.155133
# std          ...                0.282750        0.281349       0.282122
# min          ...                0.000000        0.000000       0.000000
# 25%          ...                0.000000        0.000000       0.000000
# 50%          ...                0.000000        0.000000       0.000000
# 75%          ...                0.230000        0.190000       0.200000
# max          ...                1.000000        1.000000       1.000000
#
#        JanelaSalaOeste  PortaCozinhaLeste  JanelaCozinhaSul  \
# count      2112.000000        2112.000000       2112.000000
# mean          0.155862           0.158736          0.157457
# std           0.283194           0.284812          0.285651
# min           0.000000           0.000000          0.000000
# 25%           0.000000           0.000000          0.000000
# 50%           0.000000           0.000000          0.000000
# 75%           0.200000           0.210000          0.200000
# max           1.000000           1.000000          1.000000
#
#        JanelaMezaninoNorte  JanelaMezaninoSul  JanelaMezaninoOeste  \
# count          2112.000000        2112.000000          2112.000000
# mean              0.153456           0.157670             0.150743
# std               0.280415           0.287414             0.278133
# min               0.000000           0.000000             0.000000
# 25%               0.000000           0.000000             0.000000
# 50%               0.000000           0.000000             0.000000
# 75%               0.172500           0.192500             0.170000
# max               1.000000           1.000000             1.000000
#
#        JanelaSegundoSul
# count            2112.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0
#
# [8 rows x 48 columns]

# %%
total = shuffle(selected)

input_file = total[header_input]
output_file = total[header_output]

total.to_csv(ambiente + "/Selected/d06_total.csv", index=False)
input_file.to_csv(ambiente + "/Selected/d06_input.csv", index=False)
output_file.to_csv(ambiente + "/Selected/d06_output.csv", index=False)
