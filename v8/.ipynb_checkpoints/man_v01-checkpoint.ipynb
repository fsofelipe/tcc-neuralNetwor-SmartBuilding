# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
header = ['Mes', 'Dia', 'Hora', 
         'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
         'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp',
         'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul' 
         ]
header_input = ['Hora', 'Temperature', 'Wind_Speed', 'Wind_Direction', 'Humidity', 'Air_Density', 'Rain_Status',
               'AreaServico_PMV', 'AreaServico_Temp', 'Circulacao_PMV', 'Circulacao_Temp', 'Casal_PMV', 'Casal_Temp', 'Banheiro_PMV', 'Banheiro_Temp', 'Jardim_PMV', 'Jardim_Temp', 'Solteiro_PMV', 'Solteiro_Temp', 'Sala_PMV', 'Sala_Temp', 'Mezanino_PMV', 'Mezanino_Temp'
               ]
header_output = [
                'PortaServicoLeste', 'JanelaServicoSul', 'JanelaCasalNorte', 'PortaCasalOeste', 'JanelaCasalOeste', 'JanelaBanheiroLeste', 'PortaBanheiroOeste', 'JanelaJardimNorte', 'JanelaJardimLeste', 'JanelaSolteiroNorte', 'PortaSolteiroSul', 'JanelaSolteiroSul', 'PortaSalaNorte', 'JanelaSalaNorte', 'PortaSalaLeste', 'JanelaSalaSul', 'JanelaSalaOeste', 'PortaCozinhaLeste', 'JanelaCozinhaSul', 'JanelaMezaninoNorte', 'JanelaMezaninoSul', 'JanelaMezaninoOeste', 'JanelaSegundoSul'
                ]
print len(header)
print (len(header_input))
print (len(header_output))
# Out:
# 48
# 23
# 23

# %%
all1 = pd.read_csv('Simulacao/simulation_all1.csv')
all0 = pd.read_csv('Simulacao/simulation_all0.csv')

# %%
def is_better(dataFrame, it, PMV_label1, PMV_label2):
    """it = iterator"""
    it = int(it)
    if (it > 0 and it < (dataFrame['Mes'].count() - 1)):
        if ((abs(dataFrame.iloc[it - 1][PMV_label1]) >= abs(dataFrame.iloc[it][PMV_label1])) and
            (abs(dataFrame.iloc[it - 1][PMV_label2]) >= abs(dataFrame.iloc[it][PMV_label2]))):
            return True
        else:
            return False
    else:
        return False
    
    #return (dataFrame.iloc(it))

# %%
selected = pd.DataFrame(columns=header)
tot = 0
c = 0

for i in xrange(1, all1['Mes'].count() - 1):
    if (is_better(all1, i, 'Sala_PMV', 'Mezanino_PMV')):
        #print i
        c = c + 1
        selected = selected.append(all1.iloc[i])

print "All_1: " +  str((c * 100.0)/8760.0) + "%"


tot = tot + c
c = 0
for i in xrange(1, all0['Mes'].count() - 1):
    if (is_better(all0, i, 'Sala_PMV', 'Mezanino_PMV')):
        #print i
        c = c + 1
        selected = selected.append(all0.iloc[i])

print "All_0: " +  str((c * 100.0)/8760.0) + "%"

for arq in xrange(1, 11):
    arquivo = pd.read_csv('Simulacao/simulation_random_' + str(arq) +'.csv')
    tot = tot + c
    c = 0
    
    for i in xrange(1, arquivo['Mes'].count() - 1):
        if (is_better(arquivo, i, 'Sala_PMV', 'Mezanino_PMV')):
            c = c + 1
            selected = selected.append(arquivo.iloc[i])
    
    print "Random_" + str(arq) + ": " +  str((c * 100.0)/8760.0) + "%"

print tot
# Out:
# All_1: 36.1643835616%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-52ae894b5e7b> in <module>()
#      18         #print i
#      19         c = c + 1
# ---> 20         selected = selected.append(all0.iloc[i])
#      21
#      22 print "All_0: " +  str((c * 100.0)/8760.0) + "%"
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4545             to_concat = [self, other]
#    4546         return concat(to_concat, ignore_index=ignore_index,
# -> 4547                       verify_integrity=verify_integrity)
#    4548
#    4549     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/reshape/concat.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/reshape/concat.pyc in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
#     408             if not self.copy:
#     409                 new_data._consolidate_inplace()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    4830     blocks = [make_block(
#    4831         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4832         placement=placement) for placement, join_units in concat_plan]
#    4833
#    4834     return BlockManager(blocks, axes)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in concatenate_join_units(join_units, concat_axis, copy)
#    4945             concat_values = concat_values.copy()
#    4946     else:
# -> 4947         concat_values = _concat._concat_compat(to_concat, axis=concat_axis)
#    4948
#    4949     return concat_values
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/dtypes/concat.pyc in _concat_compat(to_concat, axis)
#     164                 to_concat = [x.astype('object') for x in to_concat]
#     165
# --> 166     return np.concatenate(to_concat, axis=axis)
#     167
#     168
#
# KeyboardInterrupt:

# %%
total = shuffle(selected)

# %%
input_file = total[header_input]
output_file = total[header_output]

# %%
total.to_csv("Selected/v01_total.csv", index=False)
input_file.to_csv("Selected/v01_input.csv", index=False)
output_file.to_csv("Selected/v01_output.csv", index=False)

# %%
total.describe()
# Out:
#                 Mes           Dia          Hora   Temperature    Wind_Speed  \
# count  37986.000000  37986.000000  37986.000000  37986.000000  37986.000000
# mean       6.508477     15.951035     11.643026     19.941818      2.485795
# std        3.404121      8.809933      6.277056      5.349529      1.795172
# min        1.000000      1.000000      0.000000     -1.200000      0.000000
# 25%        4.000000      8.000000      7.000000     16.400000      1.400000
# 50%        7.000000     16.000000     11.000000     20.700000      2.100000
# 75%        9.000000     24.000000     17.000000     23.900000      3.100000
# max       12.000000     31.000000     23.000000     36.000000     40.600000
#
#        Wind_Direction      Humidity   Air_Density   Rain_Status  \
# count    37986.000000  37986.000000  37986.000000  37986.000000
# mean       151.375244     73.544016      1.169086      0.010530
# std        101.864022     15.581962      0.031519      0.102076
# min          0.000000     16.000000      1.089685      0.000000
# 25%         90.000000     62.000000      1.144910      0.000000
# 50%        140.000000     75.000000      1.163410      0.000000
# 75%        230.000000     86.000000      1.191481      0.000000
# max        360.000000    100.000000      1.290899      1.000000
#
#        AreaServico_PMV        ...         JanelaSalaNorte  PortaSalaLeste  \
# count     37986.000000        ...            37986.000000    37986.000000
# mean         -0.884334        ...                0.495940        0.497601
# std           1.236162        ...                0.334245        0.334211
# min          -5.333117        ...                0.000000        0.000000
# 25%          -1.792235        ...                0.194006        0.194495
# 50%          -0.841936        ...                0.492507        0.502146
# 75%           0.170738        ...                0.798241        0.795888
# max           2.287849        ...                1.000000        1.000000
#
#        JanelaSalaSul  JanelaSalaOeste  PortaCozinhaLeste  JanelaCozinhaSul  \
# count   37986.000000     37986.000000       37986.000000      37986.000000
# mean        0.497532         0.496862           0.494596          0.495507
# std         0.333676         0.333453           0.333660          0.334446
# min         0.000000         0.000000           0.000000          0.000000
# 25%         0.196852         0.194455           0.194891          0.193489
# 50%         0.498509         0.498617           0.491017          0.494015
# 75%         0.797695         0.796356           0.795111          0.798080
# max         1.000000         1.000000           1.000000          1.000000
#
#        JanelaMezaninoNorte  JanelaMezaninoSul  JanelaMezaninoOeste  \
# count         37986.000000       37986.000000         37986.000000
# mean              0.493591           0.495812             0.493298
# std               0.333145           0.333390             0.334067
# min               0.000000           0.000000             0.000000
# 25%               0.193827           0.195032             0.191071
# 50%               0.489650           0.495371             0.490529
# 75%               0.792897           0.794516             0.793093
# max               1.000000           1.000000             1.000000
#
#        JanelaSegundoSul
# count           37986.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0
#
# [8 rows x 48 columns]
